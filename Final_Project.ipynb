# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd drive/MyDrive/AdvDeepLearning/nanoGPT/
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AdvDeepLearning/nanoGPT
# 'Adagrad Attention'   LICENSE		    sample.py
# 'Adam Attention'      model.py		    scaling_laws.ipynb
#  Baseline	     'Momentum Attention'   test
#  Benchmark	     'Muon Attention'	    test.py
#  bench.py	      out		    train.py
#  config		      __pycache__	    transformer_sizing.ipynb
#  configurator.py      README.md		    wandb
#  data		     'RMSProp Attention'

# %%
# !pip install -q torch numpy transformers datasets tiktoken wandb tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 39.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.5 MB/s eta 0:00:00
# ...

# %%
# !python ./data/shakespeare/prepare.py --trust_remote_code=True
# Out:
# train has 301,966 tokens
# val has 36,059 tokens

# %%
# !python train.py --wandb_project="Advance Deep Learning Project" \
                 --wandb_run_name="Baseline" \
                 --out_dir="Baseline" \
                 --batch_size=12 \
                 --attention_layer="CausalSelfAttention" \
                 --momentum_eta=0.90
# Out:
# Streaming output truncated to the last 5000 lines.
# iter 1268: loss 5.1886, time 382.79ms, mfu 4.44%
# iter 1269: loss 5.3042, time 399.77ms, mfu 4.45%
# iter 1270: loss 5.2509, time 378.88ms, mfu 4.48%
# iter 1271: loss 5.1959, time 388.70ms, mfu 4.50%
# iter 1272: loss 5.2901, time 402.56ms, mfu 4.50%
# iter 1273: loss 5.2899, time 389.48ms, mfu 4.52%
# iter 1274: loss 5.2018, time 393.97ms, mfu 4.53%
# iter 1275: loss 5.3683, time 388.49ms, mfu 4.54%
# iter 1276: loss 5.0964, time 402.70ms, mfu 4.54%
# iter 1277: loss 5.1489, time 375.66ms, mfu 4.57%
# iter 1278: loss 5.1770, time 414.39ms, mfu 4.55%
# iter 1279: loss 5.1774, time 368.93ms, mfu 4.59%
# step 1280: train loss 5.1920, val loss 5.5818
# saving checkpoint to Baseline
# iter 1280: loss 5.2699, time 3254.01ms, mfu 4.18%
# iter 1281: loss 5.3405, time 383.01ms, mfu 4.24%
# iter 1282: loss 5.1879, time 393.09ms, mfu 4.28%
# iter 1283: loss 5.2477, time 388.08ms, mfu 4.32%
# ...

# %%
# !python train.py --wandb_project="Advance Deep Learning Project" \
                 --wandb_run_name="Momentum Attention" \
                 --out_dir="test" \
                 --batch_size=12 \
                 --attention_layer="MomentumAttention" \
                 --momentum_eta=0.90
# Out:
# Overriding: wandb_project = Advance Deep Learning Project
# Overriding: wandb_run_name = Momentum Attention
# Overriding: out_dir = test
# Overriding: batch_size = 12
# Overriding: attention_layer = MomentumAttention
# Overriding: momentum_eta = 0.9
# config_keys: ['out_dir', 'eval_interval', 'log_interval', 'eval_iters', 'eval_only', 'always_save_checkpoint', 'init_from', 'wandb_log', 'wandb_project', 'wandb_run_name', 'dataset', 'gradient_accumulation_steps', 'batch_size', 'block_size', 'n_layer', 'n_head', 'n_embd', 'dropout', 'bias', 'attention_layer', 'momentum_eta', 'learning_rate', 'max_iters', 'weight_decay', 'beta1', 'beta2', 'grad_clip', 'decay_lr', 'warmup_iters', 'lr_decay_iters', 'min_lr', 'backend', 'device', 'dtype', 'compile']
# ...

# %%
# !python train.py --wandb_project="Advance Deep Learning Project" \
                 --wandb_run_name="Adagrad Attention" \
                 --out_dir="Adagrad Attention" \
                 --batch_size=12 \
                 --attention_layer="AdaGradAttention" \
                 --momentum_eta=0.90
# Out:
# Streaming output truncated to the last 5000 lines.
# iter 1287: loss 5.5564, time 541.95ms, mfu 3.16%
# iter 1288: loss 5.6077, time 542.93ms, mfu 3.18%
# iter 1289: loss 5.5856, time 547.97ms, mfu 3.19%
# iter 1290: loss 5.6302, time 539.54ms, mfu 3.21%
# iter 1291: loss 5.7056, time 543.86ms, mfu 3.22%
# iter 1292: loss 5.6448, time 558.30ms, mfu 3.23%
# iter 1293: loss 5.5996, time 542.51ms, mfu 3.24%
# iter 1294: loss 5.6647, time 543.29ms, mfu 3.25%
# iter 1295: loss 5.4798, time 542.61ms, mfu 3.26%
# iter 1296: loss 5.6332, time 542.81ms, mfu 3.27%
# iter 1297: loss 5.5870, time 543.38ms, mfu 3.27%
# iter 1298: loss 5.5973, time 541.82ms, mfu 3.28%
# iter 1299: loss 5.6300, time 543.67ms, mfu 3.29%
# step 1300: train loss 5.6043, val loss 5.8435
# saving checkpoint to Adagrad Attention
# iter 1300: loss 5.6637, time 3919.26ms, mfu 3.01%
# iter 1301: loss 5.6068, time 545.19ms, mfu 3.04%
# iter 1302: loss 5.5535, time 542.53ms, mfu 3.07%
# ...

# %%
# !python train.py --wandb_project="Advance Deep Learning Project" \
                 --wandb_run_name="RMSProp Attention" \
                 --out_dir="RMSProp Attention" \
                 --batch_size=12 \
                 --attention_layer="RMSPropAttention" \
                 --momentum_eta=0.90 \
                 --beta1=0.9 \
                 --beta2=0.95
# Out:
# Streaming output truncated to the last 5000 lines.
# iter 1270: loss 5.5560, time 541.09ms, mfu 3.20%
# iter 1271: loss 5.5161, time 541.42ms, mfu 3.22%
# iter 1272: loss 5.5683, time 541.38ms, mfu 3.23%
# iter 1273: loss 5.5569, time 543.05ms, mfu 3.24%
# iter 1274: loss 5.4855, time 541.78ms, mfu 3.25%
# iter 1275: loss 5.6448, time 541.22ms, mfu 3.26%
# iter 1276: loss 5.4209, time 1110.04ms, mfu 3.10%
# iter 1277: loss 5.4337, time 543.39ms, mfu 3.13%
# iter 1278: loss 5.4963, time 542.08ms, mfu 3.15%
# iter 1279: loss 5.4841, time 541.64ms, mfu 3.17%
# step 1280: train loss 5.4931, val loss 5.7250
# saving checkpoint to RMSProp Attention
# iter 1280: loss 5.5505, time 3789.57ms, mfu 2.90%
# iter 1281: loss 5.6002, time 542.05ms, mfu 2.94%
# iter 1282: loss 5.5042, time 542.31ms, mfu 2.98%
# iter 1283: loss 5.5412, time 543.47ms, mfu 3.02%
# iter 1284: loss 5.4936, time 543.01ms, mfu 3.05%
# iter 1285: loss 5.4589, time 542.99ms, mfu 3.08%
# ...

# %%
# !python train.py --wandb_project="Advance Deep Learning Project" \
                 --wandb_run_name="Adam Attention" \
                 --out_dir="Adam Attention" \
                 --batch_size=12 \
                 --attention_layer="AdamAttention" \
                 --momentum_eta=0.90 \
                 --beta1=0.9 \
                 --beta2=0.95
# Out:
# Overriding: wandb_project = Advance Deep Learning Project
# Overriding: wandb_run_name = Adam Attention
# Overriding: out_dir = Adam Attention
# Overriding: batch_size = 12
# Overriding: attention_layer = AdamAttention
# Overriding: momentum_eta = 0.9
# Overriding: beta1 = 0.9
# Overriding: beta2 = 0.95
# config_keys: ['out_dir', 'eval_interval', 'log_interval', 'eval_iters', 'eval_only', 'always_save_checkpoint', 'init_from', 'wandb_log', 'wandb_project', 'wandb_run_name', 'dataset', 'gradient_accumulation_steps', 'batch_size', 'block_size', 'n_layer', 'n_head', 'n_embd', 'dropout', 'bias', 'attention_layer', 'momentum_eta', 'learning_rate', 'max_iters', 'weight_decay', 'beta1', 'beta2', 'grad_clip', 'decay_lr', 'warmup_iters', 'lr_decay_iters', 'min_lr', 'backend', 'device', 'dtype', 'compile']
# ...

# %%
# !python train.py --wandb_project="Advance Deep Learning Project" \
                 --wandb_run_name="Muon Attention" \
                 --out_dir="Muon Attention" \
                 --batch_size=12 \
                 --attention_layer="MuonAttention" \
                 --momentum_eta=0.90
